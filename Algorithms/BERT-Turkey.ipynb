# %%
import pandas as pd
import random 
from bertopic import BERTopic

from bert_helpers import * 
import sys
sys.path.append('../helpers_python')
from pre_processing import *
from helpers import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Chose the country

# %%
country = 'Turkey'

# Load data
df = load_data_bert(country)

# array that can save the models
saved_models = []

# %% [markdown]
# ## Set parameters

# %%
## Best params until now but cannot catch coronavirus
params_france = {
    'UMAP' : {
        'metric' : 'cosine', 
        'n_neighbors' : 15, 
        'n_components' : 20, 
        'min_dist' : 0.3, 
        'low_memory' : False,
        'random_state': 8
    },
    'HDBSCAN': {
        'min_cluster_size':15,
        'min_samples': 1,
        'cluster_selection_epsilon': 0.6,
        'metric': 'euclidean',                      
        'cluster_selection_method': 'eom',
        'prediction_data': True}
}

# %% [markdown]
# ## Train model with french parameters
# Using the french parameters we find 4 topics:
# 1. Politics of Turkey and tweets that are against  the state order. Two party and their leader are cited Gergerlioglu that defend human right and Erdogan than is the Prime minister from the right
# 1. Woman right and muslim religion
# 1. Police and jail
# 1. Revolts
#
# A lot of topics are mixed and we can see on the vizualisation that there might be clusters inside clusters

# %%
tweets = df.clean.to_list()
tweets_sub = random.sample(tweets,k=int(len(tweets)*0.2))

# %%
model_fr = get_model(params_france, additional_stop_words= [])
topics_fr, probs_fr = model_fr.fit_transform(tweets_sub)
model_fr.get_topic_info()
# Out:
# Batches:   0%|          | 0/33 [00:00<?, ?it/s]
# 2022-12-17 18:03:00,202 - BERTopic - Transformed documents to Embeddings
# 2022-12-17 18:03:15,757 - BERTopic - Reduced dimensionality
# 2022-12-17 18:03:16,078 - BERTopic - Clustered reduced embeddings
#    Topic  Count                             Name
# 0     -1    189    -1_continue_hpg_prison_people
# 1      0    436               0_say_life_god_one
# 2      1    415  1_turkey_turkish_people_kurdish
# 3      2     16       2_tweet_twitter_tag_follow

# %%
model_fr.get_topics()
# Out:
# {-1: [('continue', 0.027934142388239158),
#   ('hpg', 0.02254576703001712),
#   ('prison', 0.022505022176422904),
#   ('people', 0.02175778295192381),
#   ('resistance', 0.020174406557373153),
#   ('camp', 0.019689862867660845),
#   ('want', 0.01955389967176741),
#   ('police', 0.019366787536394897),
#   ('house', 0.018994960390026804),
#   ('day', 0.018857273655944258)],
#  0: [('say', 0.039538063044033),
#   ('life', 0.030884439875588258),
#   ('god', 0.02903674101039711),
#   ('one', 0.026811276264926253),
#   ('child', 0.025890103443839126),
#   ('mother', 0.025489818210189225),
#   ('hakan', 0.023512045641005556),
#   ('year', 0.02049849647810913),
#   ('prison', 0.020187912283320005),
#   ('justice', 0.019624293055014643)],
#  1: [('turkey', 0.05253238116704927),
#   ('turkish', 0.048903769580161814),
#   ('people', 0.044066497907941544),
#   ('kurdish', 0.03940554563544222),
#   ('gergerlio', 0.02575295456500725),
#   ('state', 0.025583585874143513),
#   ('kurd', 0.024107590750244563),
#   ('march', 0.023814673955813978),
#   ('erdogan', 0.02357042969261022),
#   ('lu', 0.022627963917390526)],
#  2: [('tweet', 0.26936280684542707),
#   ('twitter', 0.1565955488684489),
#   ('tag', 0.14282566248767806),
#   ('follow', 0.12495761908063417),
#   ('account', 0.12214467936330746),
#   ('rt', 0.10092244331071613),
#   ('tap', 0.10092244331071613),
#   ('hack', 0.10092244331071613),
#   ('tt', 0.10092244331071613),
#   ('icon', 0.10092244331071613)]}

# %%
get_tweets_of_topic(topics_fr, 2, tweets_sub, 15)
# Out:
# ['news story anything tweet',
#  'akp mhp supporter water news men curse shook social medium one',
#  'think unfollowed mistake understand course easy secret follower current follower',
#  'type password account hack enable two step protection setting change password',
#  'beg tag tweet tell follow anyway come guy play dm',
#  'aim anyway thank',
#  'fit unidad political force denounces million active ingredient produce p',
#  'follow person twitter allow say follow increase allow h seyin ga',
#  'tag tt list terrible attack tag rain tweet far tweet system',
#  'get start go live twitter tap tweet composer icon tap camera icon select live bott',
#  'please share rt',
#  'like comment tt please either tweet retweet ver rkiye gazi hapiste',
#  'unfollowing anyone rt tweet anl yonmu',
#  'ya hack',
#  'say pk kci thousand troll spammed account account suspend twitter say intense spam attack']

# %%
model_fr.visualize_heatmap()
# Out:
# <div>                            <div id="d862795b-5c95-45c1-ab48-7a7d1bf3cadf" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d862795b-5c95-45c1-ab48-7a7d1bf3cadf")) {                    Plotly.newPlot(                        "d862795b-5c95-45c1-ab48-7a7d1bf3cadf",                        [{"coloraxis":"coloraxis","name":"0","x":["0_turkey_people_turkish","1_kck_leadership_officer"],"y":["0_turkey_people_turkish","1_kck_leadership_officer"],"z":[[0.9999999999999997,0.7678959989068677],[0.7678959989068677,0.9999999999999987]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>y: %{y}<br>Similarity Score: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar", ...

# %%
model_fr.visualize_documents(tweets_sub)
# Out:
# <div>                            <div id="5ac405a9-1718-4a45-9c7f-8802df93435c" class="plotly-graph-div" style="height:750px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ac405a9-1718-4a45-9c7f-8802df93435c")) {                    Plotly.newPlot(                        "5ac405a9-1718-4a45-9c7f-8802df93435c",                        [{"hoverinfo":"text","hovertext":["soldier policeman mythical people people prisoner pkk year tc dia","commander murat karayilan make assessment suleyman soysuz listen well","pathetic antic eric trump criticises scottish debate family golf course golf guardian","hunger strike resistance continue third day prison kurdistan turkey isolation imrali","first bomb year come house k kl video turkey trend place queue thank interest","excuse guy swallow reset tape shoe box money counter montage dub coup","everyone know uighur turk torture concentration camp uyghur girl force marriage want","clear open","hunger strike isolation th day hunger strike nci g nde","break bread suspect figure","na r en ak r insidious n r en ak r worth take castle asli empty tin solid dry copper","hpg likely everyone camp prisoner held shot kill chemical gas city reach","police attack ptt resister want make voice heard ankara worker detain struggle","aim ecps economic research program erp examine populist economic developrime ministerents global regional","hz come power justice omar act beyond abu jahl shame kept alive","pkk pajk prisoner struggle continue leader free","turkish style left romance taner ak article title drop damn weapon publish ahval february","love","look necessary name","resistance isolation day acl k grevine ol","collapse continue durr palace near stadium damage november earthquake","person legally power country responsible work positive negative period ew","berzani daesh house middle east act authority b mre xiyaneta pdk","acceptable youth everything free","france strasbourg mosque imam drancy call dissolution mil g r association religious leader","human right action plan put language youth stop slur look real issue","beauty program","perin ek sought face screen like hollywood star achieve fame last period life put forward idea","thief gang mafayawari organization","gazi bilal konak disability result bomb explosion year sentence upheld take prison prison","trial former police officer derek chauvin kill george floyd suffocate continue","soylu word military operation carry enter heart pkk come end face strong resistance","saudi arabia close school mecca medina affiliate turkish ministry national education meb high education","organize campaign second season fongogo ask tweet soon","yusuf pekmezci epitome compassion life keep alive lifetime ill smail severe cancer patient come buy shroud","ankara courthouse public worker sibel bala arrest support ksel resistance wednesday tomorrow","new method despot carry deception veil law example mussolini despotism","two turkish teacher living iraq detain way back erbil international kyiv borispol airport teacher turkish","hour ago police officer name cahit demir march towards truth netherlands land exile rest peace mecca","trump travel scotland play golf say sturgeon say quite agree","animal magnetism","get married wear gold bracelet ram horn take father law house answer yes please ask","exo isi enter city also ask leave accept sent anyway one day suru","take hostage mr demirtasi say make president","first axis forum call recognition mother tongue component","main interlocutor must also explain apologize","ideology abdullah calan whole world free calan free ocalan biji berxwedana gerila sma","gaslighting men make woman look crazy lastesis metoo","half court lillard","stop attack engal bi heavy ne leyzin","voice million oppress voiceless turkey mer faruk gergerlio lu want sentence","t ...

# %% [markdown]
# ## Find parameters that are more adapted to Turkey
#
# 1. Tweets related to kurdistan and the questio of security around it
# 1. Tweets related to prison
# 1. All tweets related to Omer Faruk Gergerlioglu
# 1. Tweets related to the army and possible conflict with russia
# 1. Tweets related to the KHK party that is close to nazis party
# 1. Tweets related to the struggle

# %%
params= {
    'UMAP' : {
        'metric' : 'cosine', 
        'n_neighbors' : 15, 
        'n_components' : 30, 
        'min_dist' : 0.2, 
        'low_memory' : False,
        'random_state': 8
    },
    'HDBSCAN': {
        'min_cluster_size':15,
        'min_samples': 1,
        'cluster_selection_epsilon': 0.5,
        'metric': 'euclidean',                      
        'cluster_selection_method': 'eom',
        'prediction_data': True}
}
model = get_model(params, additional_stop_words= [])
topics, probs = model.fit_transform(tweets_sub)
model.get_topic_info()
# Out:
# Batches:   0%|          | 0/33 [00:00<?, ?it/s]
# 2022-12-17 13:27:18,196 - BERTopic - Transformed documents to Embeddings
# 2022-12-17 13:27:26,564 - BERTopic - Reduced dimensionality
# 2022-12-17 13:27:26,721 - BERTopic - Clustered reduced embeddings
#     Topic  Count                                Name
# 0      -1    225          -1_people_newroz_right_one
# 1       0    278       0_turkey_turkish_kurdish_kurd
# 2       1    232           1_gergerlio_lu_say_people
# 3       2     91           2_woman_march_freedom_day
# 4       3     90           3_parliament_vote_akp_hdp
# 5       4     34     4_account_mehmet_baransu_course
# 6       5     33    5_osman_service_publication_book
# 7       6     23         6_university_student_azi_bo
# 8       7     18    7_prison_isolation_hunger_strike
# 9       8     16  8_vaccine_corona_treat_coronavirus
# 10      9     16             9_kck_officer_pt_kanter

# %%
get_tweets_of_topic(topics_fr, 2, tweets_sub, 15)
# Out:
# []

# %%
model.get_topics()
# Out:
# {-1: [('people', 0.0269694805226164),
#   ('newroz', 0.023030446614633892),
#   ('right', 0.022604352873812968),
#   ('one', 0.020992527672773195),
#   ('police', 0.02033768140030585),
#   ('terrorist', 0.020018986580170612),
#   ('say', 0.019111962550127193),
#   ('human', 0.017506735045125885),
#   ('death', 0.017272834960975418),
#   ('like', 0.016557308499935364)],
#  0: [('turkey', 0.06417184137227112),
#   ('turkish', 0.06051693368862293),
#   ('kurdish', 0.03962279508071177),
#   ('kurd', 0.026629805372155767),
#   ('attack', 0.025825107354068344),
#   ('state', 0.025157593277810728),
#   ('erdogan', 0.024356427331305767),
#   ('year', 0.02342747686593441),
#   ('people', 0.023288636503777115),
#   ('kill', 0.01990884337321266)],
#  1: [('gergerlio', 0.04375398092454129),
#   ('lu', 0.04109871258934767),
#   ('say', 0.03193757068868136),
#   ('people', 0.026000822432012027),
#   ('god', 0.024954639147307747),
#   ('life', 0.024830512158400177),
#   ('mfg', 0.024319563718664696),
#   ('hand', 0.022822121276876224),
#   ('heart', 0.02229293340877597),
#   ('make', 0.021972037668061876)],
#  2: [('woman', 0.10725456671538335),
#   ('march', 0.10006230782461699),
#   ('freedom', 0.07536802176582426),
#   ('day', 0.051646234761477935),
#   ('martyr', 0.050815047783291274),
#   ('fighter', 0.03494580692674247),
#   ('apo', 0.033796868664207246),
#   ('fight', 0.03249249153874671),
#   ('remember', 0.03249249153874671),
#   ('international', 0.0314953664554832)],
#  3: [('parliament', 0.03863306981034406),
#   ('vote', 0.037047177785347905),
#   ('akp', 0.03674986503503462),
#   ('hdp', 0.03342478335044515),
#   ('justice', 0.03307487853153116),
#   ('court', 0.03278452723820101),
#   ('law', 0.030568684470541535),
#   ('member', 0.030373190839297796),
#   ('year', 0.028588519800758386),
#   ('decree', 0.028422658077172532)],
#  4: [('account', 0.09904139934346788),
#   ('mehmet', 0.06400521993618717),
#   ('baransu', 0.05851979690185153),
#   ('course', 0.0569380744226451),
#   ('youth', 0.05554437857071329),
#   ('reporter', 0.04887273660793732),
#   ('free', 0.04876266581916185),
#   ('tweet', 0.045260779755546224),
#   ('journalist', 0.041658283928034966),
#   ('new', 0.040330638017753)],
#  5: [('osman', 0.07454454876159283),
#   ('service', 0.06707287718512471),
#   ('publication', 0.06177436656960664),
#   ('book', 0.05782929782336361),
#   ('sent', 0.04633077492720498),
#   ('half', 0.04633077492720498),
#   ('perfection', 0.04633077492720498),
#   ('story', 0.04337197336752271),
#   ('dr', 0.041166740754842814),
#   ('today', 0.037956606915119276)],
#  6: [('university', 0.21123462310468746),
#   ('student', 0.20841240662672494),
#   ('azi', 0.1523939425561154),
#   ('bo', 0.14945255997480952),
#   ('rector', 0.11181063856722584),
#   ('appointment', 0.09953189290445176),
#   ('protest', 0.078847121625622),
#   ('bosphorus', 0.0745404257114839),
#   ('bogazici', 0.0745404257114839),
#   ('akp', 0.06860906362053992)],
#  7: [('prison', 0.16722380303365736),
#   ('isolation', 0.1369741287093812),
#   ('hunger', 0.12615367630781116),
#   ('strike', 0.12615367630781116),
#   ('prisoner', 0.1015734258467413),
#   ('pkk', 0.09434158854187377),
#   ('leader', 0.08695992160097349),
#   ('people', 0.08646056615946168),
#   ('lord', 0.08048113833786817),
#   ('abdullah', 0.07618006938505596)],
#  8: [('vaccine', 0.2595136725385865),
#   ('corona', 0.17807406689708036),
#   ('treat', 0.12975683626929324),
#   ('coronavirus', 0.11722593864429208),
#   ('intensive', 0.1113766446507415),
#   ('care', 0.09731762720196993),
#   ('virus', 0.08365262987643057),
#   ('finally', 0.08365262987643057),
#   ('postpartum', 0.07815062576286139),
#   ('hospital', 0.07815062576286139)],
#  9: [('kck', 0.13170761174274623),
#   ('officer', 0.09536076237803763),
#   ('pt', 0.07733922384802072),
#   ('kanter', 0.07225246532792846),
#   ('claim', 0.06864724009919917),
#   ('leadership', 0.06864724009919917),
#   ('meeting', 0.06357384158535842),
#   ('ber', 0.061648213717359325),
#   ('co', 0.05851373214210362),
#   ('vote', 0.057201774505049756)]}

# %%
model.visualize_documents(tweets_sub)
# Out:
# <div>                            <div id="b82ad712-3270-4cd1-bfbb-c8ecc533de67" class="plotly-graph-div" style="height:750px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b82ad712-3270-4cd1-bfbb-c8ecc533de67")) {                    Plotly.newPlot(                        "b82ad712-3270-4cd1-bfbb-c8ecc533de67",                        [{"hoverinfo":"text","hovertext":["sardinian antonio gramsci school magazine il bene comune sardinian department teacher union","clear clear would biden say putin say murderer phone come message","believe deposit money bank member community cease crime passport return","graduate left country year ago could longer breathe okay go okay go decision","prevent take picture police threaten detain follow news past day","mafia gang thief cheeky dishonest degenerate ignorant rascal never credible honest honest educate dignify never","halk n vekiline dokunma touch one proud say deputy","continue ask tonight yusuf bilge tun h seyin galip kidnap like bandit","similar video well man complete psychopath","ver rkiye gazi hapiste bila policeman lose eye hand bomb try destroy zmir explode","today learn erdogan attack protestors act political violence take place sheridan circ","information police commit suicide ey p sultan region istanbul","belgian parliament prepares recognize uighur genocide","r ber apo path success forget u history look interlotor calan red line","hunt eren keskin receive death threat soylu statement","desire overcome buffer system however restoration work intervene international system","hard exit biden putin murderer","akp mean kurdish massacre akp mean fascism unemployment humanity democracy everything else name human right","final dame p r ene p r gary p ro co p ant p r harry p r hoodie p r na p r","lgbrights human right","father mustafa tun cry help whose son kidnap month ago","stand reason judge dictator hamburg alternative link","need action evidence crime group declare terrorist grandparent baby want terrorist","li akademiya eh ala cebo torena dawikirina dewreya perwerdeya eh ervan","wake another day shame horror","memory right supreme memory sacrifice occasional objection e dumanl editorial choice day sometimes","let piss corp wait herd dead dog continue pkk","well probably watch raise wolf alread","poem naz mm describes armenian genocide compose artist genco erkal","lagim rat maglukat provide transition animal food human scum","barbara anna kirstler tkp ml honorary member mk immortalize dersim february tkprime ministerl ti kko kkb","happen solidarity teamwork","bak postac direniyor","girk leg il axa til ko er mart co kuyla r lilad mart kutlamas na girk leg il axa til ko er","birle erek kazanaca z live people union","ministry give permission poison citizen gmo animal feed another year","start support please victory bless mother","think creature even street gang wear raunchy uniform back become cop","interview h jar zozan commander female guerrilla action yja star limited heftanin","right","halabja name massacre people divide four part smell apple zilan dersim halabja roboski one","han p narl life alone ayd n rap strangle death old neighbor","great conversation friend human right democracy thank friendship amp sup","ak ener receive death threat rostrum erdo bah eli via","susamam","erdogan regime hate speech ahval","body ground shot fell","enya ar ailesine adalet","report zozan hiwa leave koban war serve revolution stay combatant","kobani fall child terrorist isi fell like ball light dictionary give kind support kobane","newroz symbol resistance oppression speak newroz celebration hesek cizre region education training commitee","say","last night ten thousand reaction violence woman samsun","self criticism accusation slander knew brave fair","police department police rap woman lawyer one one woman ...

# %%
get_coherence(model,tweets_sub, topics)
# Out:
# 0.6603577843041664
